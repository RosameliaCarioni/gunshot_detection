# %% [markdown]
# # This notebook gets/downloads all sounds from the data frames

# %%
import pandas as pd

# %%
ecoguns = pd.read_csv('data/ecoguns/Guns_Training_ecoGuns_SST.txt', delimiter = "\t")
ecoguns = ecoguns.drop(columns= ['view', 'channel', 'begin path', 'duration (s)', 'time', 'distance(m)', 'calibre', 'angle', 'elevation', 'uniqueID', 'date'])
ecoguns['delta time (s)'] =  ecoguns['end time'] - ecoguns['begin time']

# %%
ecoguns
# Out:
#       Selection  begin time    end time  low freq  high freq  \
# 0             1  28839.0174  28839.9729        10        900
# 1             2  28843.1979  28844.2331        10        900
# 2             3  28846.5024  28847.6570        10        900
# 3             4  28852.0366  28853.1514        10        900
# 4             5  28854.6245  28855.6995        10        900
# ...         ...         ...         ...       ...        ...
# 1090       1921  31262.1188  31263.2336        10        900
# 1091       1922  31264.7068  31265.7420        10        900
# 1092       1923  31273.5853  31274.7797        10        900
# 1093       1924  31280.9908  31282.1454        10        900
# 1094       1925  31334.6721  31335.8665        10        900
#
#                      Begin File  File Offset (s)   site  numshots site.1  \
# 0     mbeli_20180517_000000.wav       28839.0174  mbeli         1  mbeli
# 1     mbeli_20180517_000000.wav       28843.1979  mbeli         1  mbeli
# ...

# %%
def get_local_sound_file_ecoguns (file_name):
    path = 'data/ecoguns/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        return data
    except:
        # return file_name
# Out:
# {'tir2000m_20180426_092825.wav', 'mbeli_20180517_000000.wav', 'tir1100m_20180426_092825.wav', 'tir500m_20180426_092825.wav', 'tir1710m_20180425_131419.wav', 'tir500m_20180517_000000.wav', 'mix1500_20161105_100332.wav', 'Tree3_20180517_000000.wav', 'tree1_20180517_000000.wav', 'mix1000_20161105_093314.wav'}

# %%
# Printing missing files names
res = set()
for file in ecoguns['Begin File']:
    res.add(get_local_sound_file_ecoguns(file))
print(res)

# %%
pnnn_dep = pd.read_csv('data/pnnn_dep/nn_Grid50_guns_dep1-7_Guns_Training.txt', delimiter = "\t")

pnnn_dep = pnnn_dep.drop(columns= ['View', 'Channel', 'Begin Path', 'uniqueID', 'Notes', 'Score final', 'ID even', 'type shot'])
pnnn_dep['delta time (s)'] =  pnnn_dep['End Time (s)'] - pnnn_dep['Begin Time (s)']
pnnn_dep
# Out:
#     Selection  Begin Time (s)  End Time (s)  Low Freq (Hz)  High Freq (Hz)  \
# 0           1    3.802536e+04  3.803098e+04        150.800         623.800
# 1           2    1.126124e+05  1.126163e+05        284.800         854.300
# 2           8    2.179818e+05  2.179943e+05          8.700         908.300
# 3           9    2.179949e+05  2.180001e+05        246.400         739.200
# 4          18    2.180339e+05  2.180391e+05        284.800         854.300
# 5          27    2.615889e+05  2.615927e+05        150.800         623.800
# 6          28    3.908804e+05  3.908832e+05         31.400         836.500
# 7          32    3.909045e+05  3.909082e+05          0.000         634.900
# 8          33    3.909106e+05  3.909126e+05         25.200         786.200
# 9          36    4.827551e+05  4.827595e+05        220.500         670.000
# 10         37    5.288658e+05  5.288706e+05        284.800         854.300
# ...

# %%
def get_local_sound_file_pnnn (file_name):
    path = 'data/pnnn_dep/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        #return data
    except:
        return file_name

files_not_local = set()
for file in pnnn_dep['Begin File']:
    files_not_local.add(get_local_sound_file_pnnn(file))


def get_amazon_sound_file_pnnn (file_name):
    import requests

    doc = requests.get('https://congo8khz-pnnn.s3.us-west-2.amazonaws.com/recordings/wav/nn01f/nn01f_20171027_000000.wav')
    with open('example.wav', 'wb') as f:
        f.write(doc.content)


for file in files_not_local:
    get_amazon_sound_file_pnnn(file)#%%
import pandas as pd
import scipy

ecoguns = pd.read_csv('data/ecoguns/Guns_Training_ecoGuns_SST.txt', delimiter = "\t")
ecoguns = ecoguns.drop(columns= ['view', 'channel', 'begin path', 'duration (s)', 'time', 'distance(m)', 'calibre', 'angle', 'elevation', 'uniqueID', 'date'])
ecoguns['delta time (s)'] =  ecoguns['end time'] - ecoguns['begin time']

# %%
ecoguns

# %%
def get_local_sound_file_ecoguns (file_name):
    path = 'data/ecoguns/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        return data
    except:
        # return file_name

# %%
# Printing missing files names
res = set()
for file in ecoguns['Begin File']:
    res.add(get_local_sound_file_ecoguns(file))
print(res)

# %%
pnnn_dep = pd.read_csv('data/pnnn_dep/nn_Grid50_guns_dep1-7_Guns_Training.txt', delimiter = "\t")

pnnn_dep = pnnn_dep.drop(columns= ['View', 'Channel', 'Begin Path', 'uniqueID', 'Notes', 'Score final', 'ID even', 'type shot'])
pnnn_dep['delta time (s)'] =  pnnn_dep['End Time (s)'] - pnnn_dep['Begin Time (s)']
pnnn_dep

# %%
def get_local_sound_file_pnnn (file_name):
    path = 'data/pnnn_dep/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        #return data
    except:
        return file_name

files_not_local = set()
for file in pnnn_dep['Begin File']:
    files_not_local.add(get_local_sound_file_pnnn(file))

# %%
def get_amazon_sound_file_pnnn (file_name):
    import requests

    doc = requests.get('https://congo8khz-pnnn.s3.us-west-2.amazonaws.com/recordings/wav/nn01f/nn01f_20171027_000000.wav')
    with open('example.wav', 'wb') as f:
        f.write(doc.content)


for file in files_not_local:
    get_amazon_sound_file_pnnn(file)#%%
import pandas as pd
import scipy

ecoguns = pd.read_csv('data/ecoguns/Guns_Training_ecoGuns_SST.txt', delimiter = "\t")
ecoguns = ecoguns.drop(columns= ['view', 'channel', 'begin path', 'duration (s)', 'time', 'distance(m)', 'calibre', 'angle', 'elevation', 'uniqueID', 'date'])
ecoguns['delta time (s)'] =  ecoguns['end time'] - ecoguns['begin time']

# %%
ecoguns

# %%
def get_local_sound_file_ecoguns (file_name):
    path = 'data/ecoguns/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        return data
    except:
        # return file_name

# %%
# Printing missing files names
res = set()
for file in ecoguns['Begin File']:
    res.add(get_local_sound_file_ecoguns(file))
print(res)

# %%
pnnn_dep = pd.read_csv('data/pnnn_dep/nn_Grid50_guns_dep1-7_Guns_Training.txt', delimiter = "\t")

pnnn_dep = pnnn_dep.drop(columns= ['View', 'Channel', 'Begin Path', 'uniqueID', 'Notes', 'Score final', 'ID even', 'type shot'])
pnnn_dep['delta time (s)'] =  pnnn_dep['End Time (s)'] - pnnn_dep['Begin Time (s)']
pnnn_dep

# %%
def get_local_sound_file_pnnn (file_name):
    path = 'data/pnnn_dep/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        #return data
    except:
        return file_name

files_not_local = set()
for file in pnnn_dep['Begin File']:
    files_not_local.add(get_local_sound_file_pnnn(file))


def get_amazon_sound_file_pnnn (file_name):
    import requests

    doc = requests.get('https://congo8khz-pnnn.s3.us-west-2.amazonaws.com/recordings/wav/nn01f/nn01f_20171027_000000.wav')
    with open('example.wav', 'wb') as f:
        f.write(doc.content)


for file in files_not_local:
    get_amazon_sound_file_pnnn(file)#%%
import pandas as pd
import scipy

ecoguns = pd.read_csv('data/ecoguns/Guns_Training_ecoGuns_SST.txt', delimiter = "\t")
ecoguns = ecoguns.drop(columns= ['view', 'channel', 'begin path', 'duration (s)', 'time', 'distance(m)', 'calibre', 'angle', 'elevation', 'uniqueID', 'date'])
ecoguns['delta time (s)'] =  ecoguns['end time'] - ecoguns['begin time']

# %%
ecoguns

# %%
def get_local_sound_file_ecoguns (file_name):
    path = 'data/ecoguns/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        return data
    except:
        # return file_name

# %%
# Printing missing files names
res = set()
for file in ecoguns['Begin File']:
    res.add(get_local_sound_file_ecoguns(file))
print(res)

# %%
pnnn_dep = pd.read_csv('data/pnnn_dep/nn_Grid50_guns_dep1-7_Guns_Training.txt', delimiter = "\t")

pnnn_dep = pnnn_dep.drop(columns= ['View', 'Channel', 'Begin Path', 'uniqueID', 'Notes', 'Score final', 'ID even', 'type shot'])
pnnn_dep['delta time (s)'] =  pnnn_dep['End Time (s)'] - pnnn_dep['Begin Time (s)']
pnnn_dep
# Out:
#     Selection  Begin Time (s)  End Time (s)  Low Freq (Hz)  High Freq (Hz)  \
# 0           1    3.802536e+04  3.803098e+04        150.800         623.800
# 1           2    1.126124e+05  1.126163e+05        284.800         854.300
# 2           8    2.179818e+05  2.179943e+05          8.700         908.300
# 3           9    2.179949e+05  2.180001e+05        246.400         739.200
# 4          18    2.180339e+05  2.180391e+05        284.800         854.300
# 5          27    2.615889e+05  2.615927e+05        150.800         623.800
# 6          28    3.908804e+05  3.908832e+05         31.400         836.500
# 7          32    3.909045e+05  3.909082e+05          0.000         634.900
# 8          33    3.909106e+05  3.909126e+05         25.200         786.200
# 9          36    4.827551e+05  4.827595e+05        220.500         670.000
# 10         37    5.288658e+05  5.288706e+05        284.800         854.300
# ...

# %%
def get_local_sound_file_pnnn (file_name):
    path = 'data/pnnn_dep/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        #return data
    except:
        return file_name

files_not_local = set()
for file in pnnn_dep['Begin File']:
    files_not_local.add(get_local_sound_file_pnnn(file))
print(files_not_local)
# Out:
# {'nn06c_20190517_000000.wav', 'nn02e_20190130_000000.wav', 'nn06d_20180411_000000.wav', 'nn09b_20180503_000000.wav', 'nn06d_20190627_000000.wav', 'nn06a_20180524_000000.wav', 'nn02g_20180824_000000.wav', 'nn02g_20190512_000000.wav', 'nn08c_20180602_000000.wav', 'nn02f_20190215_000000.wav', 'nn02b_20180405_000000.wav', 'nn01g_20181117_000000.wav', 'nn02b_20180406_000000.wav', 'nn05d_20191024_000000.wav', 'nn05b_20180321_000000.wav', 'nn07b_20180517_000000.wav', 'nn02f_20180117_000000.wav', 'nn05f_20190630_000000.wav', 'nn03c_20190214_000000.wav', 'nn10b_20180531_000000.wav', 'nn05c_20171210_000000.wav', 'nn08a_20180424_000000.wav', 'nn06e_20180129_000000.wav', 'nn05f_20190412_000000.wav', 'nn02b_20180223_000000.wav', 'nn03d_20190117_000000.wav', 'nn02a_20180721_000000.wav', 'nn04d_20190111_000000.wav', 'nn05b_20180320_000000.wav', 'nn02d_20180122_000000.wav', 'nn05b_20180102_000000.wav', 'nn06b_20181003_000000.wav', 'nn10a_20191025_000000.wav', 'nn06c_20181210_000000.wav', 'nn07c_2018
# ...

# %%
# https://stackoverflow.com/questions/39128738/downloading-a-song-through-python-requests
def get_amazon_sound_file_pnnn (file_name):
    import requests
    site = file_name.split('_')[0]
    doc = requests.get(f'https://congo8khz-pnnn.s3.us-west-2.amazonaws.com/recordings/wav/{site}/{file_name}')
    with open(f"data/aws_downloads/{file_name}", 'wb') as f:
        f.write(doc.content)

get_amazon_sound_file_pnnn('nn06c_20190517_000000.wav')

files_not_aws = set()

for file in files_not_local[1:]:
    try: get_amazon_sound_file_pnnn(file)
    except Exception:
        files_not_aws.add(get_local_sound_file_pnnn(file))#%%
import pandas as pd
import scipy

ecoguns = pd.read_csv('data/ecoguns/Guns_Training_ecoGuns_SST.txt', delimiter = "\t")
ecoguns = ecoguns.drop(columns= ['view', 'channel', 'begin path', 'duration (s)', 'time', 'distance(m)', 'calibre', 'angle', 'elevation', 'uniqueID', 'date'])
ecoguns['delta time (s)'] =  ecoguns['end time'] - ecoguns['begin time']

# %%
ecoguns

# %%
def get_local_sound_file_ecoguns (file_name):
    path = 'data/ecoguns/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        return data
    except:
        # return file_name

# %%
# Printing missing files names
res = set()
for file in ecoguns['Begin File']:
    res.add(get_local_sound_file_ecoguns(file))
print(res)

# %%
pnnn_dep = pd.read_csv('data/pnnn_dep/nn_Grid50_guns_dep1-7_Guns_Training.txt', delimiter = "\t")

pnnn_dep = pnnn_dep.drop(columns= ['View', 'Channel', 'Begin Path', 'uniqueID', 'Notes', 'Score final', 'ID even', 'type shot'])
pnnn_dep['delta time (s)'] =  pnnn_dep['End Time (s)'] - pnnn_dep['Begin Time (s)']
pnnn_dep

# %%
def get_local_sound_file_pnnn (file_name):
    path = 'data/pnnn_dep/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        #return data
    except:
        return file_name

files_not_local = set()
for file in pnnn_dep['Begin File']:
    files_not_local.add(get_local_sound_file_pnnn(file))


def get_amazon_sound_file_pnnn (file_name):
    import requests

    doc = requests.get('https://congo8khz-pnnn.s3.us-west-2.amazonaws.com/recordings/wav/nn01f/nn01f_20171027_000000.wav')
    with open('example.wav', 'wb') as f:
        f.write(doc.content)


for file in files_not_local:
    get_amazon_sound_file_pnnn(file)#%%
import pandas as pd
import scipy

ecoguns = pd.read_csv('data/ecoguns/Guns_Training_ecoGuns_SST.txt', delimiter = "\t")
ecoguns = ecoguns.drop(columns= ['view', 'channel', 'begin path', 'duration (s)', 'time', 'distance(m)', 'calibre', 'angle', 'elevation', 'uniqueID', 'date'])
ecoguns['delta time (s)'] =  ecoguns['end time'] - ecoguns['begin time']

# %%
ecoguns

# %%
def get_local_sound_file_ecoguns (file_name):
    path = 'data/ecoguns/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        return data
    except:
        # return file_name

# %%
# Printing missing files names
res = set()
for file in ecoguns['Begin File']:
    res.add(get_local_sound_file_ecoguns(file))
print(res)

# %%
pnnn_dep = pd.read_csv('data/pnnn_dep/nn_Grid50_guns_dep1-7_Guns_Training.txt', delimiter = "\t")

pnnn_dep = pnnn_dep.drop(columns= ['View', 'Channel', 'Begin Path', 'uniqueID', 'Notes', 'Score final', 'ID even', 'type shot'])
pnnn_dep['delta time (s)'] =  pnnn_dep['End Time (s)'] - pnnn_dep['Begin Time (s)']
pnnn_dep

# %%
def get_local_sound_file_pnnn (file_name):
    path = 'data/pnnn_dep/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        #return data
    except:
        return file_name

files_not_local = set()
for file in pnnn_dep['Begin File']:
    files_not_local.add(get_local_sound_file_pnnn(file))

# %%
def get_amazon_sound_file_pnnn (file_name):
    import requests

    doc = requests.get('https://congo8khz-pnnn.s3.us-west-2.amazonaws.com/recordings/wav/nn01f/nn01f_20171027_000000.wav')
    with open('example.wav', 'wb') as f:
        f.write(doc.content)


for file in files_not_local:
    get_amazon_sound_file_pnnn(file)#%%
import pandas as pd
import scipy

ecoguns = pd.read_csv('data/ecoguns/Guns_Training_ecoGuns_SST.txt', delimiter = "\t")
ecoguns = ecoguns.drop(columns= ['view', 'channel', 'begin path', 'duration (s)', 'time', 'distance(m)', 'calibre', 'angle', 'elevation', 'uniqueID', 'date'])
ecoguns['delta time (s)'] =  ecoguns['end time'] - ecoguns['begin time']

# %%
ecoguns

# %%
def get_local_sound_file_ecoguns (file_name):
    path = 'data/ecoguns/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        return data
    except:
        # return file_name

# %%
# Printing missing files names
res = set()
for file in ecoguns['Begin File']:
    res.add(get_local_sound_file_ecoguns(file))
print(res)

# %%
pnnn_dep = pd.read_csv('data/pnnn_dep/nn_Grid50_guns_dep1-7_Guns_Training.txt', delimiter = "\t")

pnnn_dep = pnnn_dep.drop(columns= ['View', 'Channel', 'Begin Path', 'uniqueID', 'Notes', 'Score final', 'ID even', 'type shot'])
pnnn_dep['delta time (s)'] =  pnnn_dep['End Time (s)'] - pnnn_dep['Begin Time (s)']
pnnn_dep

# %%
def get_local_sound_file_pnnn (file_name):
    path = 'data/pnnn_dep/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        #return data
    except:
        return file_name

files_not_local = set()
for file in pnnn_dep['Begin File']:
    files_not_local.add(get_local_sound_file_pnnn(file))


def get_amazon_sound_file_pnnn (file_name):
    import requests

    doc = requests.get('https://congo8khz-pnnn.s3.us-west-2.amazonaws.com/recordings/wav/nn01f/nn01f_20171027_000000.wav')
    with open('example.wav', 'wb') as f:
        f.write(doc.content)


for file in files_not_local:
    get_amazon_sound_file_pnnn(file)#%%
import pandas as pd
import scipy

ecoguns = pd.read_csv('data/ecoguns/Guns_Training_ecoGuns_SST.txt', delimiter = "\t")
ecoguns = ecoguns.drop(columns= ['view', 'channel', 'begin path', 'duration (s)', 'time', 'distance(m)', 'calibre', 'angle', 'elevation', 'uniqueID', 'date'])
ecoguns['delta time (s)'] =  ecoguns['end time'] - ecoguns['begin time']

# %%
ecoguns

# %%
def get_local_sound_file_ecoguns (file_name):
    path = 'data/ecoguns/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        return data
    except Exception:
        # return file_name

# %%
# Printing missing files names
res = set()
for file in ecoguns['Begin File']:
    res.add(get_local_sound_file_ecoguns(file))
print(res)

# %%
pnnn_dep = pd.read_csv('data/pnnn_dep/nn_Grid50_guns_dep1-7_Guns_Training.txt', delimiter = "\t")

pnnn_dep = pnnn_dep.drop(columns= ['View', 'Channel', 'Begin Path', 'uniqueID', 'Notes', 'Score final', 'ID even', 'type shot'])
pnnn_dep['delta time (s)'] =  pnnn_dep['End Time (s)'] - pnnn_dep['Begin Time (s)']
pnnn_dep

# %%
def get_local_sound_file_pnnn (file_name):
    path = 'data/pnnn_dep/Sounds/' + file_name
    try:
        samplerate, data = scipy.io.wavfile.read(path)
        #return data
    except:
        return file_name

files_not_local = set()
for file in pnnn_dep['Begin File']:
    files_not_local.add(get_local_sound_file_pnnn(file))
print(files_not_local)

# %%
# https://stackoverflow.com/questions/39128738/downloading-a-song-through-python-requests
def get_amazon_sound_file_pnnn (file_name):
    import requests
    site = file_name.split('_')[0]
    doc = requests.get(f'https://congo8khz-pnnn.s3.us-west-2.amazonaws.com/recordings/wav/{site}/{file_name}')
    with open(f"data/aws_downloads/{file_name}", 'wb') as f:
        f.write(doc.content)

files_not_aws = set()

for file in list(files_not_local)[1:]:
    try:
        get_amazon_sound_file_pnnn(file)
    except Exception:
        files_not_aws.add(get_local_sound_file_pnnn(file))

# %% [markdown]
# ## Reading from "other" file, which contains sounds no generated by gunshots

# %%
other = pd.read_csv('data/other/ecoGuns_SST_Guns_Training-OtherSounds.txt', delimiter = "\t")
other = other.drop (columns=['View', 'Channel', 'Begin Path', 'site', 'uniqueID', 'Notes', 'Score final', 'ID even', 'type shot', 'total shots', 'Tags', 'Final'])
other['delta time (s)'] =  other['End Time (s)'] - other['Begin Time (s)']
# Out:
#     Selection  Begin Time (s)  End Time (s)  Low Freq (Hz)  High Freq (Hz)  \
# 0         176          0.2924       0.81871          3.788         931.818
# 1         187     482989.4590  483000.21920        166.667         965.909
# 2         189     483005.2137  483010.88620        121.212         981.061
# 3         191     483033.2839  483036.61730        117.424         969.697
# 4         195     512169.5652  512171.67050        287.879         973.485
# ..        ...             ...           ...            ...             ...
# 89        275     587942.2174  587955.55470        165.316        1249.595
# 90        276     661844.8364  661866.53230        194.489        1021.070
# 91        277     752403.3676  752435.82060        145.867        1103.728
# 92        282     823938.2274  823952.25540        149.289         966.825
# 93        284     431721.8376  431734.73880        191.943        1037.915
#
# ...

# %%
other_distinct = pd.unique(other['Begin File'])

# %%
def get_amazon_sound_file_other (file_name):
    import requests
    site = file_name.split('_')[0]
    doc = requests.get(f'https://congo8khz-pnnn.s3.us-west-2.amazonaws.com/recordings/wav/{site}/{file_name}')
    with open(f"data/aws_other/{file_name}", 'wb') as f:
        f.write(doc.content)

files_not_aws = set()

for file in other_distinct:
    try:
        get_amazon_sound_file_other(file)
    except Exception:
        files_not_aws.add(file)
